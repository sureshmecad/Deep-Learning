# %%
import cv2
import os
import numpy as np

# %%
#This module resizes image from a given directory to 100*100 pixels and writes all images to given directory
count=0

for path, subdirnames, filenames in os.walk("trainingImages"):

    for filename in filenames:
      if filename.startswith("."):
        print("Skipping File:",filename)#Skipping files that startwith .
        continue
      img_path=os.path.join(path, filename)#fetching image path
      print("img_path",img_path)
      id=os.path.basename(path)#fetching subdirectory names
      img = cv2.imread(img_path)
      if img is None:
        print("Image not loaded properly")
        continue
      resized_image = cv2.resize(img, (100, 100))
      new_path="resizedTrainingImages"+"/"+str(id)
      print("desired path is",os.path.join(new_path, "frame%d.jpg" % count))#write all images to resizedTrainingImages/id directory
      cv2.imwrite(os.path.join(new_path, "frame%d.jpg" % count),resized_image)
      count += 1
# Out:
# Skipping File: .DS_Store
# Skipping File: .DS_Store
# img_path trainingImages\0\2018-priyanka-chopra-wallpaper.jpg
# desired path is resizedTrainingImages/0\frame0.jpg
# img_path trainingImages\0\ashley-graham-background-images-hd-520x245.jpg
# desired path is resizedTrainingImages/0\frame1.jpg
# img_path trainingImages\0\beautiful-priyanka-chopra-wallpapers.jpg
# desired path is resizedTrainingImages/0\frame2.jpg
# img_path trainingImages\0\fifa-world-cup-2018-winner-antoine-griezmann-wallpaper-520x245.jpg
# desired path is resizedTrainingImages/0\frame3.jpg
# img_path trainingImages\0\p1.jpeg
# desired path is resizedTrainingImages/0\frame4.jpg
# img_path trainingImages\0\p1.jpg
# desired path is resizedTrainingImages/0\frame5.jpg
# img_path trainingImages\0\p10.jpg
# desired path is resizedTrainingImages/0\frame6.jpg
# img_path trainingImages\0\p11.jpeg
# desired path is resizedTrainingImages/0\frame7.jpg
# img_path trainingImages\0\p3.jpg
# desired path is resizedTrainingImages/0\frame8.jpg
# img_path trainingImages\0\p4.jpg
# desired path is resizedTrainingImages/0\frame9.jpg
# img_path trainingImages\0\p5.jpg
# desired path is resizedTrainingImages/0\frame10.jpg
# img_path trainingImages\0\p9.jpg
# desired path is resizedTrainingImages/0\frame11.jpg
# img_path trainingImages\0\priyanka-chopra-4k-wallpaper.jpg
# desired path is resizedTrainingImages/0\frame12.jpg
# img_path trainingImages\0\priyanka-chopra-759-filephoto.jpg
# desired path is resizedTrainingImages/0\frame13.jpg
# img_path trainingImages\0\priyanka-chopra-background-images-hd.jpg
# desired path is resizedTrainingImages/0\frame14.jpg
# img_path trainingImages\0\priyanka-chopra-fea.jpg
# desired path is resizedTrainingImages/0\frame15.jpg
# img_path trainingImages\0\priyanka-chopra-full-hd-image.jpg
# desired path is resizedTrainingImages/0\frame16.jpg
# img_path trainingImages\0\priyanka-chopra-full-hd-photo.jpg
# desired path is resizedTrainingImages/0\frame17.jpg
# img_path trainingImages\0\priyanka-chopra-full-hd.jpg
# desired path is resizedTrainingImages/0\frame18.jpg
# img_path trainingImages\0\priyanka-chopra-full-image.jpg
# desired path is resizedTrainingImages/0\frame19.jpg
# img_path trainingImages\0\priyanka-chopra-hd-photo.jpg
# desired path is resizedTrainingImages/0\frame20.jpg
# img_path trainingImages\0\priyanka-chopra-hd-pics.jpg
# desired path is resizedTrainingImages/0\frame21.jpg
# img_path trainingImages\0\priyanka-chopra-hd-picture.jpg
# desired path is resizedTrainingImages/0\frame22.jpg
# img_path trainingImages\0\priyanka-chopra-hd-wallpaper.jpg
# desired path is resizedTrainingImages/0\frame23.jpg
# img_path trainingImages\0\priyanka-chopra-hd.jpg
# desired path is resizedTrainingImages/0\frame24.jpg
# img_path trainingImages\0\priyanka-chopra-hot-hd-pics.jpg
# desired path is resizedTrainingImages/0\frame25.jpg
# img_path trainingImages\0\priyanka-chopra-hot-hd-wallpaper.jpg
# desired path is resizedTrainingImages/0\frame26.jpg
# img_path trainingImages\0\priyanka-chopra-hot-hd.jpg
# desired path is resizedTrainingImages/0\frame27.jpg
# img_path trainingImages\0\priyanka-chopra-hot-images.jpg
# desired path is resizedTrainingImages/0\frame28.jpg
# img_path trainingImages\0\priyanka-chopra-hot-photos.jpg
# desired path is resizedTrainingImages/0\frame29.jpg
# img_path trainingImages\0\priyanka-chopra-hot-photoshoot.jpg
# desired path is resizedTrainingImages/0\frame30.jpg
# img_path trainingImages\0\priyanka-chopra-hot-pics.jpg
# desired path is resizedTrainingImages/0\frame31.jpg
# img_path trainingImages\0\priyanka-chopra-hot-picture.jpg
# desired path is resizedTrainingImages/0\frame32.jpg
# img_path trainingImages\0\priyanka-chopra-hot-wallpaper.jpg
# desired path is resizedTrainingImages/0\frame33.jpg
# img_path trainingImages\0\priyanka-chopra-image-download.jpg
# desired path is resizedTrainingImages/0\frame34.jpg
# img_path trainingImages\0\priyanka-chopra-image-in-saree.jpg
# desired path is resizedTrainingImages/0\frame35.jpg
# img_path trainingImages\0\priyanka-chopra-image-photo.jpg
# desired path is resizedTrainingImages/0\frame36.jpg
# img_path trainingImages\0\priyanka-chopra-image.jpg
# desired path is resizedTrainingImages/0\frame37.jpg
# img_path trainingImages\0\priyanka-chopra-images-download-free.jpg
# desired path is resizedTrainingImages/0\frame38.jpg
# img_path trainingImages\0\priyanka-chopra-ka-wallpaper.jpg
# desired path is resizedTrainingImages/0\frame39.jpg
# img_path trainingImages\0\priyanka-chopra-ki-image.jpg
# desired path is resizedTrainingImages/0\frame40.jpg
# img_path trainingImages\0\priyanka-chopra-ki-photo.jpg
# desired path is resizedTrainingImages/0\frame41.jpg
# img_path trainingImages\0\priyanka-chopra-ki-picture.jpg
# desired path is resizedTrainingImages/0\frame42.jpg
# img_path trainingImages\0\priyanka-chopra-latest-images.jpg
# desired path is resizedTrainingImages/0\frame43.jpg
# img_path trainingImages\0\priyanka-chopra-latest-photos.jpg
# desired path is resizedTrainingImages/0\frame44.jpg
# img_path trainingImages\0\priyanka-chopra-latest-pics.jpg
# desired path is resizedTrainingImages/0\frame45.jpg
# img_path trainingImages\0\priyanka-chopra-new-photo.jpg
# desired path is resizedTrainingImages/0\frame46.jpg
# img_path trainingImages\0\priyanka-chopra-new-photoshoot.jpg
# desired path is resizedTrainingImages/0\frame47.jpg
# img_path trainingImages\0\priyanka-chopra-new-pics.jpg
# desired path is resizedTrainingImages/0\frame48.jpg
# img_path trainingImages\0\priyanka-chopra-photo-download.jpg
# desired path is resizedTrainingImages/0\frame49.jpg
# img_path trainingImages\0\priyanka-chopra-photo-gallery-latest.jpg
# desired path is resizedTrainingImages/0\frame50.jpg
# img_path trainingImages\0\priyanka-chopra-photo-gallery.jpg
# desired path is resizedTrainingImages/0\frame51.jpg
# img_path trainingImages\0\priyanka-chopra-photo-wallpaper.jpg
# desired path is resizedTrainingImages/0\frame52.jpg
# img_path trainingImages\0\priyanka-chopra-photo.jpg
# desired path is resizedTrainingImages/0\frame53.jpg
# img_path trainingImages\0\priyanka-chopra-pics.jpg
# desired path is resizedTrainingImages/0\frame54.jpg
# img_path trainingImages\0\priyanka-chopra-pictures.jpg
# desired path is resizedTrainingImages/0\frame55.jpg
# img_path trainingImages\0\priyanka-chopra-wallpaper-2018.jpg
# desired path is resizedTrainingImages/0\frame56.jpg
# img_path trainingImages\0\priyanka-chopra-wallpaper-for-android.jpg
# desired path is resizedTrainingImages/0\frame57.jpg
# img_path trainingImages\0\priyanka-chopra-wallpaper-for-galaxy-note.jpg
# desired path is resizedTrainingImages/0\frame58.jpg
# img_path trainingImages\0\priyanka-chopra-wallpaper-for-iphone.jpg
# desired path is resizedTrainingImages/0\frame59.jpg
# img_path trainingImages\0\priyanka-chopra-wallpaper-for-mobile.jpg
# desired path is resizedTrainingImages/0\frame60.jpg
# img_path trainingImages\0\priyanka-chopra-wallpaper-for-phone.jpg
# desired path is resizedTrainingImages/0\frame61.jpg
# img_path trainingImages\0\priyanka-chopra-wallpaper-for-samsung.jpg
# desired path is resizedTrainingImages/0\frame62.jpg
# img_path trainingImages\0\priyanka-chopra-wallpaper.jpg
# desired path is resizedTrainingImages/0\frame63.jpg
# img_path trainingImages\0\priyanka-chopra-wallpapers-latest-photos.jpg
# desired path is resizedTrainingImages/0\frame64.jpg
# img_path trainingImages\0\priyanka-chopra-wallpapers-latest.jpg
# desired path is resizedTrainingImages/0\frame65.jpg
# img_path trainingImages\0\priyanka-chopra-wallpapers-new.jpg
# desired path is resizedTrainingImages/0\frame66.jpg
# img_path trainingImages\0\priyanka-chopra.jpeg
# desired path is resizedTrainingImages/0\frame67.jpg
# img_path trainingImages\0\priyanka-hd-images.jpg
# desired path is resizedTrainingImages/0\frame68.jpg
# img_path trainingImages\0\priyanka-hd-photo.jpg
# desired path is resizedTrainingImages/0\frame69.jpg
# img_path trainingImages\0\priyanka-hd.jpg
# desired path is resizedTrainingImages/0\frame70.jpg
# img_path trainingImages\0\priyanka-hot-images.jpg
# desired path is resizedTrainingImages/0\frame71.jpg
# Skipping File: .DS_Store
# img_path trainingImages\1\05_07_2018_kng_shdi_1_18160994.jpg
# desired path is resizedTrainingImages/1\frame72.jpg
# img_path trainingImages\1\111508_dajgqajfcw_1548486838.jpeg
# desired path is resizedTrainingImages/1\frame73.jpg
# img_path trainingImages\1\220px_Kangana_Ranaut_at_Fever_104_FM_Studios.jpg
# desired path is resizedTrainingImages/1\frame74.jpg
# img_path trainingImages\1\435069_kangana.jpg
# desired path is resizedTrainingImages/1\frame75.jpg
# img_path trainingImages\1\58567_tksenxnhbd_1495192424.jpg
# desired path is resizedTrainingImages/1\frame76.jpg
# img_path trainingImages\1\5c4b0acea3227.image.jpg
# desired path is resizedTrainingImages/1\frame77.jpg
# img_path trainingImages\1\67896457.jpg
# desired path is resizedTrainingImages/1\frame78.jpg
# img_path trainingImages\1\aa_Cover_567vnisio43sb4ngroftgfljf1_20180619225555.Medi.jpeg
# desired path is resizedTrainingImages/1\frame79.jpg
# img_path trainingImages\1\aa_Cover_eulmdrl8o8mb02jipd06fca9b2_20170422105843.Medi.jpeg
# desired path is resizedTrainingImages/1\frame80.jpg
# img_path trainingImages\1\banner_7_much_loved_kangana_ranaut_fashion_looks_1535029191.jpg
# desired path is resizedTrainingImages/1\frame81.jpg
# img_path trainingImages\1\Blue_Kangana_d.jpg
# desired path is resizedTrainingImages/1\frame82.jpg
# img_path trainingImages\1\dc_Cover_fuvdkphnaid742mnsdmuq60i16_20171210110652.Medi_0.jpeg
# desired path is resizedTrainingImages/1\frame83.jpg
# img_path trainingImages\1\gsGtZIOd_400x400.jpg
# desired path is resizedTrainingImages/1\frame84.jpg
# img_path trainingImages\1\have_been_harassed_by_actors_on_sets__says_kangana_ranaut_2019_01_21.jpg
# desired path is resizedTrainingImages/1\frame85.jpg
# img_path trainingImages\1\indian_bollywood_actress_kangana_ranaut_showcases_a_creation_by_at_picture_id1092782148.jpg
# desired path is resizedTrainingImages/1\frame86.jpg
# img_path trainingImages\1\Inside_Kangana_Ranaut_Starrer_Manikarnikas_Wrap_Up_Party.jpg
# desired path is resizedTrainingImages/1\frame87.jpg
# img_path trainingImages\1\jhansia_actress_kangana_ranaut_addresses_success_manikarnika_768fe3a0_4d38_11e9_9111_3135b956f139.jpg
# desired path is resizedTrainingImages/1\frame88.jpg
# img_path trainingImages\1\Kan.jpg
# desired path is resizedTrainingImages/1\frame89.jpg
# img_path trainingImages\1\kangana ranaut PTI 750x500.jpg
# desired path is resizedTrainingImages/1\frame90.jpg
# img_path trainingImages\1\Kangana.jpg
# desired path is resizedTrainingImages/1\frame91.jpg
# img_path trainingImages\1\kangana_ranaut (1).jpg
# desired path is resizedTrainingImages/1\frame92.jpg
# img_path trainingImages\1\Kangana_Ranaut.gif
# Image not loaded properly
# img_path trainingImages\1\Kangana_Ranaut1_2.jpg
# desired path is resizedTrainingImages/1\frame93.jpg
# img_path trainingImages\1\kangana_ranaut_1505378148.jpeg
# desired path is resizedTrainingImages/1\frame94.jpg
# img_path trainingImages\1\kangana_ranaut_1521814856.jpeg
# desired path is resizedTrainingImages/1\frame95.jpg
# img_path trainingImages\1\kangana_ranaut_1524646227.jpeg
# desired path is resizedTrainingImages/1\frame96.jpg
# img_path trainingImages\1\kangana_ranaut_1553246965.jpeg
# desired path is resizedTrainingImages/1\frame97.jpg
# img_path trainingImages\1\kangana_ranaut_21.jpg
# desired path is resizedTrainingImages/1\frame98.jpg
# img_path trainingImages\1\kangana_ranaut_biopic_1550215104__rend_16_9.jpg
# desired path is resizedTrainingImages/1\frame99.jpg
# img_path trainingImages\1\Kangana_Ranaut_g_d.jpg
# desired path is resizedTrainingImages/1\frame100.jpg
# img_path trainingImages\1\kangana_ranaut_i_want_to_have_babies_and_enjoy_motherhood_19_1482123573.jpg
# desired path is resizedTrainingImages/1\frame101.jpg
# img_path trainingImages\1\Kangana_Ranaut_krish.jpg
# desired path is resizedTrainingImages/1\frame102.jpg
# img_path trainingImages\1\Kangana_Ranaut_rare_pictures.jpg
# desired path is resizedTrainingImages/1\frame103.jpg
# img_path trainingImages\1\kangana_ranaut_slams_to_karni_sena_says_shell_destroy_them_if_they_continue_to_harass_her_1547805217_725x725.jpg
# desired path is resizedTrainingImages/1\frame104.jpg
# img_path trainingImages\1\Kangana_Ranaut_Tomatoheart_6.jpg
# desired path is resizedTrainingImages/1\frame105.jpg
# img_path trainingImages\1\kangana_saree_look_anita_dongre.jpg
# desired path is resizedTrainingImages/1\frame106.jpg
# img_path trainingImages\1\kangnaranaut001.jpg
# desired path is resizedTrainingImages/1\frame107.jpg
# img_path trainingImages\1\Kangna_Ranaut_1900x.jpg
# desired path is resizedTrainingImages/1\frame108.jpg
# img_path trainingImages\1\kangna_ranaut_20150417103630_164.jpg
# desired path is resizedTrainingImages/1\frame109.jpg
# img_path trainingImages\1\Manikarnika_bg_1.jpg
# desired path is resizedTrainingImages/1\frame110.jpg
# img_path trainingImages\1\maxresdefault.jpg
# desired path is resizedTrainingImages/1\frame111.jpg
# img_path trainingImages\1\mumbai_actress_kangana_ranaut_awards_marathi_taraka_a51d3edc_187e_11e9_9a47_fd04d5270281.jpg
# desired path is resizedTrainingImages/1\frame112.jpg
# img_path trainingImages\1\MV5BMTA2NTg0ODA1ODJeQTJeQWpwZ15BbWU4MDM0NDkxNTMy._V1_UY317_CR5_0_214_317_AL_.jpg
# desired path is resizedTrainingImages/1\frame113.jpg
# img_path trainingImages\1\nationalherald_2019_02_da01d787_7539_45d2_b1a2_e9969b8071ea_Kanagana_ranaut.jpg
# desired path is resizedTrainingImages/1\frame114.jpg
# img_path trainingImages\1\session_paliwal_actress_kangana_ranaut_masterclass_signature_6791aa46_4ca2_11e9_aca9_eac9e517f545.jpg
# desired path is resizedTrainingImages/1\frame115.jpg
